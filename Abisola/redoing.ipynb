# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time
from collections import defaultdict

# %%
driver = webdriver.Chrome(r"C:\Users\olaka\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\olaka\AppData\Local\Temp\ipykernel_4124\1970852803.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\olaka\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.bestbuy.ca/en-ca/category/televisions/21344')

# %%
driver.maximize_window()

# %%
no_of_items = driver.find_elements_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/main/div[1]/div[3]/div[2]/div[1]/div/div[1]')
# Out:
# C:\Users\olaka\AppData\Local\Temp\ipykernel_4124\4039194325.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   no_of_items = driver.find_elements_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/main/div[1]/div[3]/div[2]/div[1]/div/div[1]')

# %%
no_of_items
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="eb70ec07131156390a0c74073d1044ba", element="0D9EECECE269840FB2CDCAF456172EB2_element_67")>]

# %%
no_of_items[0].text
# Out:
# '1,047 results'

# %%
no_of_items_element = driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/main/div[1]/div[3]/div[2]/div[1]/div/div[1]')
no_of_items_text = no_of_items_element.text.split()[0]
no_of_items_text = no_of_items_element.text.split()[0]
no_of_items = int(no_of_items_text.replace(',', ''))

# Calculate the number of times to click the "Show More" button
no_of_show_more_clicks = no_of_items // 29
# Out:
# C:\Users\olaka\AppData\Local\Temp\ipykernel_4124\2994157825.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   no_of_items_element = driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/main/div[1]/div[3]/div[2]/div[1]/div/div[1]')

# %%
no_of_show_more_clicks
# Out:
# 36

# %%
for _ in range(no_of_show_more_clicks):
    driver.find_elements_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/main/div[1]/div[3]/div[2]/a/div')[0].click()
    time.sleep(3)
# Out:
# C:\Users\olaka\AppData\Local\Temp\ipykernel_4124\2755299087.py:2: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   driver.find_elements_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/main/div[1]/div[3]/div[2]/a/div')[0].click()

# %%
array = []
for i in range(1,no_of_show_more_clicks*29):
    try:
        search = driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/main/div[1]/div[4]/div/div/ul/div/div[{}]'.format(i))
        array.append(search.text)
    except:
        print('Out of Index')
# Out:
# C:\Users\olaka\AppData\Local\Temp\ipykernel_4124\4064033118.py:4: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search = driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/main/div[1]/div[4]/div/div/ul/div/div[{}]'.format(i))
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index
# Out of Index

# %%
array[:5]
# Out:
# ['Sponsored\nLG 43" 4K UHD HDR LED webOS Smart TV (43UQ7590PUB) - 2022 - Dark Iron Grey\n(1808 Reviews)\n$449.99\n$449.99\nPlus $12.20 EHF\nAvailable to ship\nSold out in nearby stores\nSponsored\nLG 86" 4K UHD HDR LED webOS Smart TV (86UQ7590PUD) - 2022 - Dark Iron Grey\n(17 Reviews)\n$1799.99\n$1,799.99\nPlus $15.50 EHF\nAvailable to ship\nSold out in nearby stores\nSamsung 50" 4K UHD HDR LED Tizen Smart TV (UN50TU690TFXZC) - 2022 - Only at Best Buy\n(864 Reviews)\nTop Deal\n$499.99\n$499.99\nSAVE $100\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nSony X85K 65" 4K UHD HDR LED Smart Google TV (KD65X85K) - 2022\n(505 Reviews)\n$1099.99\n$1,099.99\nSAVE $200\nPlus $15.50 EHF\nAvailable to ship\nSold out in nearby stores\nSamsung 65" 4K UHD HDR QLED Smart TV (QN65Q60CAFXZC) - 2023 - Titan Grey\n(163 Reviews)\nTop Deal\n$1099.99\n$1,099.99\nSAVE $200\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nOpen Box - Samsung 70" 4K UHD HDR LED Tizen OS Smart TV (UN70TU6985FXZC) - 2020\n(3 Reviews)\n$629.99\n$629.99\nSAVE $70\nPlus $15.50 EHF\nAvailable to ship\nSold out in nearby stores\nSamsung 32" 1080p HD LED Tizen Smart TV (UN32N5300AFXZC) - Glossy Black\n(7792 Reviews)\n$299.99\n$299.99\nAvailable to ship\nAvailable at nearby stores\nExplore Sony’s full TV lineup. \nBring the cinematic experience home with Sony.\nLearn more\nPhilips 50" 4K UHD HDR LCD Direct Lit Roku Smart TV (50PUL6673/F6) - 2023\n(2 Reviews)\nTop Deal\n$399.99\n$399.99\nSAVE $50\nAvailable to ship\nAvailable at nearby stores\nLG 65" 4K UHD HDR QNED webOS Smart TV (65QNED80UQA) - 2022 - Dark Titan Silver/Ashed Blue\n(935 Reviews)\n$894.98\n$894.98\nSAVE $505\nPlus $15.50 EHF\nSold out online\nSold out in nearby stores\nSamsung 43" 4K UHD HDR LED Tizen Smart TV (UN43TU690TFXZC) - 2022 - Only at Best Buy\n(1127 Reviews)\n$499.99\n$499.99\nPlus $12.20 EHF\nAvailable to ship\nAvailable at nearby stores\nSamsung 55" 4K UHD HDR LED Tizen Smart TV (UN55CU7000FXZC) - 2023 - Titan Grey\n(513 Reviews)\nTop Deal\n$699.99\n$699.99\nSAVE $50\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nSony BRAVIA 75" 4K UHD HDR LED Google TV Smart TV (XR75X90K) - 2022\n(681 Reviews)\n$1799.99\n$1,799.99\nSAVE $200\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nHisense 40" 1080p HD LED VIDAA Smart TV (40A4KV) - 2023\n(3 Reviews)\n$249.99\n$249.99\nPlus $12.20 EHF\nAvailable to ship\nSold out in nearby stores\nOpen Box - Samsung 65" 4K UHD HDR LED Tizen Smart TV (UN65TU7000FXZC) - Titan Grey\n(6 Reviews)\n$679.99\n$679.99\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nSamsung 55" 4K UHD OLED Tizen Smart TV (QN55S95BAFXZC)\n(1575 Reviews)\n$1799.99\n$1,799.99\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nTCL 50" S-Class 4K UHD HDR LED Smart Google TV (50S450G-CA) - 2023\n(34 Reviews)\n$399.99\n$399.99\nAvailable to ship\nAvailable at nearby stores\nTCL 55" S-Class 4K UHD HDR LED Smart Google TV (55S450G-CA) - 2023\n(38 Reviews)\n$449.99\n$449.99\nAvailable to ship\nAvailable at nearby stores\nSamsung 65" 4K UHD HDR LED Tizen Smart TV (UN65TU690TFXZC) - 2022 - Only at Best Buy\n(466 Reviews)\n$799.99\n$799.99\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nSamsung 65" 4K UHD Neo QLED Tizen Smart TV (QN65QN90BAFXZC) - Titan Black\n(209 Reviews)\n$1799.99\n$1,799.99\nSAVE $200\nPlus $15.50 EHF\nAvailable to ship\nSold out in nearby stores\nHisense 58" 4K UHD HDR LED Roku Smart TV (58R63G) - 2022\n(1 Review)\n$479.99\n$479.99\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nTCL 43" S-Class 4K UHD HDR LED Smart Google TV (43S450G-CA) - 2023\n(39 Reviews)\n$329.99\n$329.99\nAvailable to ship\nAvailable at nearby stores\nSamsung 55" 4K UHD HDR LED Tizen Smart TV (UN55TU690TFXZC) - 2022 - Only at Best Buy\n(52 Reviews)\n$699.99\n$699.99\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nSamsung 55" 4K UHD HDR LED Tizen Smart TV (UN55TU7000FXZC) - Tit ...

# %%
array[0]
# Out:
# 'Sponsored\nLG 43" 4K UHD HDR LED webOS Smart TV (43UQ7590PUB) - 2022 - Dark Iron Grey\n(1808 Reviews)\n$449.99\n$449.99\nPlus $12.20 EHF\nAvailable to ship\nSold out in nearby stores\nSponsored\nLG 86" 4K UHD HDR LED webOS Smart TV (86UQ7590PUD) - 2022 - Dark Iron Grey\n(17 Reviews)\n$1799.99\n$1,799.99\nPlus $15.50 EHF\nAvailable to ship\nSold out in nearby stores\nSamsung 50" 4K UHD HDR LED Tizen Smart TV (UN50TU690TFXZC) - 2022 - Only at Best Buy\n(864 Reviews)\nTop Deal\n$499.99\n$499.99\nSAVE $100\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nSony X85K 65" 4K UHD HDR LED Smart Google TV (KD65X85K) - 2022\n(505 Reviews)\n$1099.99\n$1,099.99\nSAVE $200\nPlus $15.50 EHF\nAvailable to ship\nSold out in nearby stores\nSamsung 65" 4K UHD HDR QLED Smart TV (QN65Q60CAFXZC) - 2023 - Titan Grey\n(163 Reviews)\nTop Deal\n$1099.99\n$1,099.99\nSAVE $200\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nOpen Box - Samsung 70" 4K UHD HDR LED Tizen OS Smart TV (UN70TU6985FXZC) - 2020\n(3 Reviews)\n$629.99\n$629.99\nSAVE $70\nPlus $15.50 EHF\nAvailable to ship\nSold out in nearby stores\nSamsung 32" 1080p HD LED Tizen Smart TV (UN32N5300AFXZC) - Glossy Black\n(7792 Reviews)\n$299.99\n$299.99\nAvailable to ship\nAvailable at nearby stores\nExplore Sony’s full TV lineup. \nBring the cinematic experience home with Sony.\nLearn more\nPhilips 50" 4K UHD HDR LCD Direct Lit Roku Smart TV (50PUL6673/F6) - 2023\n(2 Reviews)\nTop Deal\n$399.99\n$399.99\nSAVE $50\nAvailable to ship\nAvailable at nearby stores\nLG 65" 4K UHD HDR QNED webOS Smart TV (65QNED80UQA) - 2022 - Dark Titan Silver/Ashed Blue\n(935 Reviews)\n$894.98\n$894.98\nSAVE $505\nPlus $15.50 EHF\nSold out online\nSold out in nearby stores\nSamsung 43" 4K UHD HDR LED Tizen Smart TV (UN43TU690TFXZC) - 2022 - Only at Best Buy\n(1127 Reviews)\n$499.99\n$499.99\nPlus $12.20 EHF\nAvailable to ship\nAvailable at nearby stores\nSamsung 55" 4K UHD HDR LED Tizen Smart TV (UN55CU7000FXZC) - 2023 - Titan Grey\n(513 Reviews)\nTop Deal\n$699.99\n$699.99\nSAVE $50\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nSony BRAVIA 75" 4K UHD HDR LED Google TV Smart TV (XR75X90K) - 2022\n(681 Reviews)\n$1799.99\n$1,799.99\nSAVE $200\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nHisense 40" 1080p HD LED VIDAA Smart TV (40A4KV) - 2023\n(3 Reviews)\n$249.99\n$249.99\nPlus $12.20 EHF\nAvailable to ship\nSold out in nearby stores\nOpen Box - Samsung 65" 4K UHD HDR LED Tizen Smart TV (UN65TU7000FXZC) - Titan Grey\n(6 Reviews)\n$679.99\n$679.99\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nSamsung 55" 4K UHD OLED Tizen Smart TV (QN55S95BAFXZC)\n(1575 Reviews)\n$1799.99\n$1,799.99\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nTCL 50" S-Class 4K UHD HDR LED Smart Google TV (50S450G-CA) - 2023\n(34 Reviews)\n$399.99\n$399.99\nAvailable to ship\nAvailable at nearby stores\nTCL 55" S-Class 4K UHD HDR LED Smart Google TV (55S450G-CA) - 2023\n(38 Reviews)\n$449.99\n$449.99\nAvailable to ship\nAvailable at nearby stores\nSamsung 65" 4K UHD HDR LED Tizen Smart TV (UN65TU690TFXZC) - 2022 - Only at Best Buy\n(466 Reviews)\n$799.99\n$799.99\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nSamsung 65" 4K UHD Neo QLED Tizen Smart TV (QN65QN90BAFXZC) - Titan Black\n(209 Reviews)\n$1799.99\n$1,799.99\nSAVE $200\nPlus $15.50 EHF\nAvailable to ship\nSold out in nearby stores\nHisense 58" 4K UHD HDR LED Roku Smart TV (58R63G) - 2022\n(1 Review)\n$479.99\n$479.99\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nTCL 43" S-Class 4K UHD HDR LED Smart Google TV (43S450G-CA) - 2023\n(39 Reviews)\n$329.99\n$329.99\nAvailable to ship\nAvailable at nearby stores\nSamsung 55" 4K UHD HDR LED Tizen Smart TV (UN55TU690TFXZC) - 2022 - Only at Best Buy\n(52 Reviews)\n$699.99\n$699.99\nPlus $15.50 EHF\nAvailable to ship\nAvailable at nearby stores\nSamsung 55" 4K UHD HDR LED Tizen Smart TV (UN55TU7000FXZC) - Tita ...

# %%
array[0].splitlines()
# Out:
# ['Sponsored',
#  'LG 43" 4K UHD HDR LED webOS Smart TV (43UQ7590PUB) - 2022 - Dark Iron Grey',
#  '(1808 Reviews)',
#  '$449.99',
#  '$449.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sponsored',
#  'LG 86" 4K UHD HDR LED webOS Smart TV (86UQ7590PUD) - 2022 - Dark Iron Grey',
#  '(17 Reviews)',
#  '$1799.99',
#  '$1,799.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 50" 4K UHD HDR LED Tizen Smart TV (UN50TU690TFXZC) - 2022 - Only at Best Buy',
#  '(864 Reviews)',
#  'Top Deal',
#  '$499.99',
#  '$499.99',
#  'SAVE $100',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony X85K 65" 4K UHD HDR LED Smart Google TV (KD65X85K) - 2022',
#  '(505 Reviews)',
#  '$1099.99',
#  '$1,099.99',
#  'SAVE $200',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 65" 4K UHD HDR QLED Smart TV (QN65Q60CAFXZC) - 2023 - Titan Grey',
#  '(163 Reviews)',
#  'Top Deal',
#  '$1099.99',
#  '$1,099.99',
#  'SAVE $200',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - Samsung 70" 4K UHD HDR LED Tizen OS Smart TV (UN70TU6985FXZC) - 2020',
#  '(3 Reviews)',
#  '$629.99',
#  '$629.99',
#  'SAVE $70',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 32" 1080p HD LED Tizen Smart TV (UN32N5300AFXZC) - Glossy Black',
#  '(7792 Reviews)',
#  '$299.99',
#  '$299.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'Explore Sony’s full TV lineup. ',
#  'Bring the cinematic experience home with Sony.',
#  'Learn more',
#  'Philips 50" 4K UHD HDR LCD Direct Lit Roku Smart TV (50PUL6673/F6) - 2023',
#  '(2 Reviews)',
#  'Top Deal',
#  '$399.99',
#  '$399.99',
#  'SAVE $50',
#  'Available to ship',
#  'Available at nearby stores',
#  'LG 65" 4K UHD HDR QNED webOS Smart TV (65QNED80UQA) - 2022 - Dark Titan Silver/Ashed Blue',
#  '(935 Reviews)',
#  '$894.98',
#  '$894.98',
#  'SAVE $505',
#  'Plus $15.50 EHF',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'Samsung 43" 4K UHD HDR LED Tizen Smart TV (UN43TU690TFXZC) - 2022 - Only at Best Buy',
#  '(1127 Reviews)',
#  '$499.99',
#  '$499.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 55" 4K UHD HDR LED Tizen Smart TV (UN55CU7000FXZC) - 2023 - Titan Grey',
#  '(513 Reviews)',
#  'Top Deal',
#  '$699.99',
#  '$699.99',
#  'SAVE $50',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony BRAVIA 75" 4K UHD HDR LED Google TV Smart TV (XR75X90K) - 2022',
#  '(681 Reviews)',
#  '$1799.99',
#  '$1,799.99',
#  'SAVE $200',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Hisense 40" 1080p HD LED VIDAA Smart TV (40A4KV) - 2023',
#  '(3 Reviews)',
#  '$249.99',
#  '$249.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Open Box - Samsung 65" 4K UHD HDR LED Tizen Smart TV (UN65TU7000FXZC) - Titan Grey',
#  '(6 Reviews)',
#  '$679.99',
#  '$679.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 55" 4K UHD OLED Tizen Smart TV (QN55S95BAFXZC)',
#  '(1575 Reviews)',
#  '$1799.99',
#  '$1,799.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'TCL 50" S-Class 4K UHD HDR LED Smart Google TV (50S450G-CA) - 2023',
#  '(34 Reviews)',
#  '$399.99',
#  '$399.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'TCL 55" S-Class 4K UHD HDR LED Smart Google TV (55S450G-CA) - 2023',
#  '(38 Reviews)',
#  '$449.99',
#  '$449.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 65" 4K UHD HDR LED Tizen Smart TV (UN65TU690TFXZC) - 2022 - Only at Best Buy',
#  '(466 Reviews)',
#  '$799.99',
#  '$799.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 65" 4K UHD Neo QLED Tizen Smart TV (QN65QN90BAFXZC) - Titan Black',
#  '(209 Reviews)',
#  '$1799.99',
#  '$1,799.99',
#  'SAVE $200',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Hisense 58" 4K UHD HDR LED Roku Smart TV (58R63G) - 2022',
#  '(1 Review)',
#  '$479.99',
#  '$479.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'TCL 43" S-Class 4K UHD HDR LED Smart Google TV (43S450G-CA) - 2023',
#  '(39 Reviews)',
#  '$329.99',
#  '$329.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 55" 4K UHD HDR LED Tizen Smart TV (UN55TU690TFXZC) - 2022 - Only at Best Buy',
#  '(52 Reviews)',
#  '$699.99',
#  '$699.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 55" 4K UHD HDR LED Tizen Smart TV (UN55TU7000FXZC) - Titan Grey',
#  '(20981 Reviews)',
#  '$649.99',
#  '$649.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'TCL 55" Q-Class 4K UHD HDR QLED Smart Google TV (55Q750G-CA) - 2023',
#  '(53 Reviews)',
#  '$749.99',
#  '$749.99',
#  'SAVE $150',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'Samsung 50" 4K UHD HDR LED Tizen Smart TV (UN50CU7000FXZC) - 2023 - Titan Grey',
#  '(390 Reviews)',
#  '$649.99',
#  '$649.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Hisense 65" 4K UHD HDR LED Roku Smart TV (65R63G) - 2022',
#  '(1 Review)',
#  '$629.99',
#  '$629.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sponsored',
#  'LG NanoCell 65" 4K UHD HDR LED webOS Smart TV (65NANO75UQA) - 2022 - Ashed Blue',
#  '(500 Reviews)',
#  '$999.99',
#  '$999.99',
#  'SAVE $400',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sponsored',
#  'LG 55" 4K UHD HDR LED webOS Smart TV (55UQ7590PUB) - 2022 - Dark Iron Grey',
#  '(44 Reviews)',
#  '$699.99',
#  '$699.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung The Frame 55" 4K UHD HDR QLED Tizen Smart TV (QN55LS03BAFXZC) - 2022 - Charcoal Black',
#  '(465 Reviews)',
#  'Top Deal',
#  '$1599.99',
#  '$1,599.99',
#  'SAVE $100',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Open Box - Samsung 75" 4K UHD HDR LED Tizen Smart TV (UN75TU7000FXZC) - Titan Grey',
#  '(2 Reviews)',
#  '$959.99',
#  '$959.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 65" 4K UHD HDR LED Tizen Smart TV (UN65CU7000FXZC) - 2023 - Titan Grey',
#  '(502 Reviews)',
#  'Top Deal',
#  '$899.99',
#  '$899.99',
#  'SAVE $50',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung The Frame 50" 4K UHD HDR QLED Tizen Smart TV (QN50LS03BAFXZC) - 2022 - Charcoal Black',
#  '(466 Reviews)',
#  '$1599.99',
#  '$1,599.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung The Frame 65" 4K UHD HDR QLED Tizen Smart TV (QN65LS03BAFXZC) - 2022 - Charcoal Black',
#  '(464 Reviews)',
#  '$2699.99',
#  '$2,699.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'LG 75" 4K UHD HDR LED webOS Smart TV (75UQ7070ZUD) - 2022 - Grey - Only at Best Buy',
#  '(926 Reviews)',
#  '$999.99',
#  '$999.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 32" 720p HD LED Tizen Smart TV (UN32M4500BFXZC) - Glossy Black',
#  '(4696 Reviews)',
#  '$199.99',
#  '$199.99',
#  'SAVE $30',
#  'Plus $7.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'TCL 40" S-Class 1080p HD HDR LED Smart Google TV (40S350G-CA) - 2023',
#  '(9 Reviews)',
#  '$269.99',
#  '$269.99',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG 55" 4K UHD HDR LED webOS Smart TV (55UQ7590PUB) - 2022 - Dark Iron Grey - Open Box',
#  '(1 Review)',
#  '$559.99',
#  '$559.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony X75K 55" 4K UHD HDR LED Smart Google TV (KD55X75K) - 2022',
#  '(618 Reviews)',
#  '$699.99',
#  '$699.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Hisense 50" 4K UHD HDR LED Roku Smart TV (50R63G) - 2022',
#  '(0 Reviews)',
#  '$399.99',
#  '$399.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 55" 4K UHD Neo QLED Tizen Smart TV (QN55QN90BAFXZC) - Titan Black',
#  '(209 Reviews)',
#  '$1499.95',
#  '$1,499.95',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG 48" 4K UHD HDR OLED webOS Evo ThinQ AI Smart TV (OLED48C2PUA) - 2022 - Dark Titan Silver',
#  '(2965 Reviews)',
#  '$1699.99',
#  '$1,699.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - Samsung 65" 4K UHD HDR LED Tizen Smart TV (UN65TU690TFXZC) - 2022',
#  '(2 Reviews)',
#  '$639.99',
#  '$639.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony BRAVIA 55" 4K UHD HDR LED Google TV Smart TV (XR55X90K) - 2022',
#  '(515 Reviews)',
#  '$1299.95',
#  '$1,299.95',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'TCL 65" Q-Class 4K UHD HDR QLED Smart Google TV (65Q750G-CA) - 2023',
#  '(3 Reviews)',
#  '$999.99',
#  '$999.99',
#  'SAVE $100',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 65" 4K UHD HDR QLED Tizen Smart TV (QN65Q60BAFXZC) - Titan Grey - Open Box',
#  '(0 Reviews)',
#  '$899.99',
#  '$899.99',
#  'SAVE $50',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony X80K 65" 4K UHD HDR LED Smart Google TV (KD65X80K) - 2022 - Open Box',
#  '(4 Reviews)',
#  '$819.99',
#  '$819.99',
#  'SAVE $30',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 85" 4K UHD HDR LED Tizen Smart TV (UN85CU7000FXZC) - 2023 - Titan Grey',
#  '(255 Reviews)',
#  '$1799.99',
#  '$1,799.99',
#  'SAVE $400',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 75" 4K UHD HDR LED Tizen Smart TV (UN75CU7000FXZC) - 2023 - Titan Grey',
#  '(405 Reviews)',
#  'Top Deal',
#  '$1299.99',
#  '$1,299.99',
#  'SAVE $200',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG 43" 4K UHD HDR LED webOS Smart TV (43UQ7590PUB) - 2022 - Dark Iron Grey',
#  '(1808 Reviews)',
#  '$449.99',
#  '$449.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG StanbyME 27" 1080p HD HDR LED webOS Smart TV (27ART10AKPL) - 2022',
#  '(53 Reviews)',
#  '$1499.99',
#  '$1,499.99',
#  'Plus $7.50 EHF',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'TCL 32" S-Class 1080p HD HDR LED Smart Google TV (32S350G-CA) - 2023',
#  '(44 Reviews)',
#  '$199.99',
#  '$199.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony BRAVIA XR A95K 65" 4K UHD HDR OLED Smart Google TV (XR65A95K) - 2022',
#  '(587 Reviews)',
#  '$3999.99',
#  '$3,999.99',
#  'SAVE $600',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 55" 4K UHD HDR QLED Smart TV (QN55Q60CAFXZC) - 2023 - Titan Grey',
#  '(213 Reviews)',
#  '$999.99',
#  '$999.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - Samsung 82" 4K UHD HDR LED Tizen OS Smart TV (UN82TU7000FXZC) - 2021 - Titan Grey',
#  '(0 Reviews)',
#  '$1199.99',
#  '$1,199.99',
#  'Plus $15.50 EHF',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'LG NanoCell 65" 4K UHD HDR LED webOS Smart TV (65NANO75UQA) - 2022 - Ashed Blue',
#  '(500 Reviews)',
#  '$999.99',
#  '$999.99',
#  'SAVE $400',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 43" 4K UHD HDR LED Tizen Smart TV (UN43CU7000FXZC) - 2023 - Titan Grey',
#  '(410 Reviews)',
#  '$549.99',
#  '$549.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony X85K 43" 4K UHD HDR LED Smart Google TV (KD43X85K) - 2022',
#  '(529 Reviews)',
#  '$819.99',
#  '$819.99',
#  'SAVE $30',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'LG 42" 4K UHD HDR OLED webOS Evo ThinQ AI Smart TV (OLED42C2PUA) - 2022 - Dark Titan Silver',
#  '(3031 Reviews)',
#  '$1599.99',
#  '$1,599.99',
#  'Plus $12.20 EHF',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'TCL 55" Q-Class 4K UHD HDR QLED Smart Google TV (55Q650G-CA) - 2023',
#  '(32 Reviews)',
#  '$549.99',
#  '$549.99',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'Samsung 85" 4K UHD HDR QLED Smart TV (QN85Q60CAFXZC) - 2023 - Titan Grey',
#  '(162 Reviews)',
#  '$2399.99',
#  '$2,399.99',
#  'SAVE $500',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony X85K 55" 4K UHD HDR LED Smart Google TV (KD55X85K) - 2022',
#  '(328 Reviews)',
#  '$1099.99',
#  '$1,099.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 70" 4K UHD HDR LED Tizen Smart TV (UN70CU7000FXZC) - 2023 - Titan Grey',
#  '(244 Reviews)',
#  '$1099.99',
#  '$1,099.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'TCL 6-Series 65" 4K UHD HDR QLED Mini-LED Roku OS Smart TV (65R635-CA)',
#  '(701 Reviews)',
#  '$1299.99',
#  '$1,299.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 75" 4K UHD HDR LED Tizen Smart TV (UN75AU8000FXZC) - 2021',
#  '(4462 Reviews)',
#  '$1299.97',
#  '$1,299.97',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Hisense 43" 4K UHD HDR LED Roku Smart TV (43R63G) - 2022',
#  '(0 Reviews)',
#  '$329.99',
#  '$329.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'LG 65" 4K UHD HDR OLED webOS Evo ThinQ AI Smart TV (OLED65C3PUA) - 2023',
#  '(72 Reviews)',
#  '$2999.99',
#  '$2,999.99',
#  'SAVE $100',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'TCL 65" S-Class 4K UHD HDR LED Smart Google TV (65S450G-CA) - 2023',
#  '(32 Reviews)',
#  '$649.99',
#  '$649.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'LG G3 65" 4K UHD HDR OLED evo Gallery webOS Smart TV (OLED65G3PUA) - 2023 - Satin Silver',
#  '(66 Reviews)',
#  '$3999.99',
#  '$3,999.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony BRAVIA XR A95K 55" 4K UHD HDR OLED Smart Google TV (XR55A95K) - 2022',
#  '(374 Reviews)',
#  '$3499.99',
#  '$3,499.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 58" 4K UHD HDR LED Tizen Smart TV (UN58CU7000FXZC) - 2023 - Titan Grey',
#  '(286 Reviews)',
#  '$849.99',
#  '$849.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - Samsung 43" 4K UHD HDR LED Tizen Smart TV (UN43TU690TFXZC) - 2022',
#  '(3 Reviews)',
#  '$399.99',
#  '$399.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung The Frame 43" 4K UHD HDR QLED Tizen Smart TV (QN43LS03BAFXZC) - 2022 - Charcoal Black',
#  '(462 Reviews)',
#  '$1099.99',
#  '$1,099.99',
#  'SAVE $100',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony BRAVIA 85" 4K UHD HDR LED Google TV Smart TV (XR85X90K) - 2022',
#  '(559 Reviews)',
#  '$2799.99',
#  '$2,799.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG 86" 4K UHD HDR LED webOS Smart TV (86UQ7590PUD) - 2022 - Dark Iron Grey',
#  '(17 Reviews)',
#  '$1799.99',
#  '$1,799.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Open Box - Insignia 32" 720p HD LED TV (NS-32D310CA21) - 2020 - Only at Best Buy',
#  '(1 Review)',
#  '$159.99',
#  '$159.99',
#  'SAVE $20',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony 65" 4K UHD HDR LED Smart Google TV (XR65X90L) - 2023',
#  '(1 Review)',
#  'Top Deal',
#  '$1899.99',
#  '$1,899.99',
#  'SAVE $100',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 55" 4K UHD HDR QLED Smart TV (QN55Q70CAFXZC) - 2023',
#  '(73 Reviews)',
#  '$1199.99',
#  '$1,199.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - Samsung 50" 4K UHD HDR QLED Tizen OS Smart TV (QN50Q80AAFXZC) - 2021 - Titan Black',
#  '(2 Reviews)',
#  '$699.99',
#  '$699.99',
#  'SAVE $180',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung The Frame 75" 4K UHD HDR QLED Tizen Smart TV (QN75LS03BAFXZC) - 2022 - Charcoal Black',
#  '(462 Reviews)',
#  '$3999.99',
#  '$3,999.99',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Open Box - Samsung 50" 4K UHD HDR LED Tizen Smart TV (UN50AU8000FXZC) - 2021',
#  '(4 Reviews)',
#  '$519.99',
#  '$519.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony X80K 55" 4K UHD HDR LED Smart Google TV (KD55X80K) - 2022',
#  '(635 Reviews)',
#  '$949.99',
#  '$949.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony X85K 50" 4K UHD HDR LED Smart Google TV (KD50X85K) - 2022',
#  '(223 Reviews)',
#  '$949.99',
#  '$949.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony X80K 50" 4K UHD HDR LED Smart Google TV (KD50X80K) - 2022',
#  '(541 Reviews)',
#  '$829.95',
#  '$829.95',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - Samsung 58" 4K UHD HDR LED Tizen Smart TV (UN58TU7000FXZC) - Titan Grey',
#  '(7 Reviews)',
#  '$583.99',
#  '$583.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony X80K 65" 4K UHD HDR LED Smart Google TV (KD65X80K) - 2022',
#  '(847 Reviews)',
#  '$1199.99',
#  '$1,199.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - LG NanoCell 75" 4K UHD HDR LED webOS Smart TV (75NANO80UPA) - 2021',
#  '(0 Reviews)',
#  '$1919.99',
#  '$1,919.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 43" 4K UHD HDR QLED Smart TV (QN43Q60CAFXZC) - 2023 - Titan Grey',
#  '(208 Reviews)',
#  '$749.99',
#  '$749.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - Samsung 65" 4K UHD HDR QLED Tizen OS Smart TV (QN65QN88AAFXZC) - 2021 - Titan Black',
#  '(0 Reviews)',
#  '$1614.99',
#  '$1,614.99',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony 85" 4K UHD HDR Mini-LED Smart Google TV (XR85X93L) - 2023',
#  '(0 Reviews)',
#  '$5499.99',
#  '$5,499.99',
#  'SAVE $800',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 85" 4K UHD HDR LED Tizen Smart TV (UN85CU8000FXZC) - 2023',
#  '(195 Reviews)',
#  '$1999.99',
#  '$1,999.99',
#  'SAVE $500',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 65" 4K UHD HDR Neo QLED Tizen Smart TV (QN65QN90CAFXZC) - 2023 - Titan Black',
#  '(22 Reviews)',
#  'Top Deal',
#  '$2799.99',
#  '$2,799.99',
#  'SAVE $500',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 65" 4K UHD HDR QLED Smart TV (QN65Q80CAFXZC) - 2023 - Titan Black',
#  '(83 Reviews)',
#  '$1699.99',
#  '$1,699.99',
#  'SAVE $100',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - Samsung 65" 4K UHD HDR QLED Tizen OS Smart TV (QN65Q70AAFXZC) - 2021',
#  '(0 Reviews)',
#  '$1199.99',
#  '$1,199.99',
#  'SAVE $75',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 50" 4K UHD HDR QLED Smart TV (QN50Q60CAFXZC) - 2023 - Titan Grey',
#  '(203 Reviews)',
#  '$849.99',
#  '$849.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 75" 4K UHD HDR QLED Tizen Smart TV (QN75Q60BAFXZC) - Titan Grey',
#  '(268 Reviews)',
#  '$1599.95',
#  '$1,599.95',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 65" 4K UHD HDR QLED Tizen Smart TV (QN65Q60BAFXZC) - Titan Grey',
#  '(278 Reviews)',
#  '$1199.95',
#  '$1,199.95',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'LG 77" 4K UHD HDR OLED webOS Evo ThinQ AI Smart TV (OLED77C3PUA) - 2023',
#  '(78 Reviews)',
#  '$4299.99',
#  '$4,299.99',
#  'SAVE $500',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony BRAVIA XR X90J 50" 4K UHD HDR LED Smart Google TV (XR50X90J) - 2021',
#  '(5051 Reviews)',
#  '$1099.99',
#  '$1,099.99',
#  'SAVE $100',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 50" 4K UHD HDR LED Tizen Smart TV (UN50CU8000FXZC) - 2023',
#  '(126 Reviews)',
#  'Top Deal',
#  '$699.99',
#  '$699.99',
#  'SAVE $50',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'TCL 6-Series 55" 4K UHD HDR QLED Mini-LED Roku OS Smart TV (55R635-CA)',
#  '(1042 Reviews)',
#  '$899.99',
#  '$899.99',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'Samsung 65" 4K UHD HDR QLED Tizen Smart TV (QN65Q75AAFXZC) - Only at Best Buy',
#  '(22 Reviews)',
#  '$1299.97',
#  '$1,299.97',
#  'SAVE $400',
#  'Plus $15.50 EHF',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'Samsung 55" 4K UHD HDR QLED Smart TV (QN55Q80CAFXZC) - 2023 - Titan Black',
#  '(55 Reviews)',
#  '$1299.99',
#  '$1,299.99',
#  'SAVE $100',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 55" 4K UHD HDR QLED Tizen Smart TV (QN55Q80BAFXZC) - Titan Black - Open Box',
#  '(1 Review)',
#  '$879.99',
#  '$879.99',
#  'SAVE $20',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG 55" 4K UHD HDR LED webOS Smart TV (55UQ7590PUB) - 2022 - Dark Iron Grey',
#  '(44 Reviews)',
#  '$699.99',
#  '$699.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'LG 65" 4K UHD HDR LED webOS Smart TV (65UQ7590PUB) - 2022 - Dark Iron Grey',
#  '(29 Reviews)',
#  '$849.99',
#  '$849.99',
#  'SAVE $50',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 55" 4K UHD HDR QLED Tizen Smart TV (QN55Q60BAFXZC) - Titan Grey - Open Box',
#  '(2 Reviews)',
#  '$679.99',
#  '$679.99',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 75" 4K UHD HDR QLED Smart TV (QN75Q60CAFXZC) - 2023 - Titan Grey',
#  '(166 Reviews)',
#  '$1999.99',
#  '$1,999.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Insignia 40" 1080p LED TV (NS-40D510CA21) - 2020 - Only at Best Buy',
#  '(23 Reviews)',
#  '$299.99',
#  '$299.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony X80K 43" 4K UHD HDR LED Smart Google TV (KD43X80K) - 2022',
#  '(487 Reviews)',
#  '$749.99',
#  '$749.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony X85K 75" 4K UHD HDR LED Smart Google TV (KD75X85K) - 2022',
#  '(285 Reviews)',
#  '$1799.99',
#  '$1,799.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Amazon Fire TV 4-Series 43" 4K UHD HDR LED Smart TV (B08T6FMSY8) - 2021',
#  '(16 Reviews)',
#  '$399.99',
#  '$399.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'Sony BRAVIA XR X95K 65" 4K UHD HDR Mini-LED Smart Google TV (XR65X95K) - 2022',
#  '(350 Reviews)',
#  '$2499.99',
#  '$2,499.99',
#  'SAVE $1,200',
#  'Plus $15.50 EHF',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'TCL 6-Series 75" 4K UHD HDR QLED Roku OS Smart TV (75R635-CA)',
#  '(435 Reviews)',
#  '$1999.99',
#  '$1,999.99',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG G3 77" 4K UHD HDR OLED evo Gallery webOS Smart TV (OLED77G3PUA) - 2023 - Satin Silver',
#  '(71 Reviews)',
#  '$5999.99',
#  '$5,999.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 77" 4K UHD HDR OLED Tizen Smart TV(QN77S95CAFXZC) - 2023 - Titan Black',
#  '(127 Reviews)',
#  'Top Deal',
#  '$5499.99',
#  '$5,499.99',
#  'SAVE $500',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG 75" 4K UHD HDR LED webOS Smart TV (75UQ7590PUB) - 2022 - Dark Iron Grey',
#  '(789 Reviews)',
#  '$1499.99',
#  '$1,499.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 65" 4K UHD HDR QLED Tizen Smart TV (QN65Q80BAFXZC) - Titan Black',
#  '(156 Reviews)',
#  '$1499.95',
#  '$1,499.95',
#  'Plus $15.50 EHF',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'LG 48" 4K UHD HDR OLED webOS ThinQ AI Smart TV (OLED48A2PUA) - 2022',
#  '(945 Reviews)',
#  '$999.99',
#  '$999.99',
#  'Plus $15.50 EHF',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'Samsung 58" 4K UHD HDR LED Tizen Smart TV (UN58TU690TFXZC) - 2023',
#  '(0 Reviews)',
#  '$699.99',
#  '$699.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - Samsung 65" 4K UHD HDR LED Tizen Smart TV (UN65AU8000FXZC) - 2021',
#  '(1689 Reviews)',
#  '$739.99',
#  '$739.99',
#  'SAVE $60',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 75" 4K UHD HDR LED Tizen Smart TV (UN75TU690TFXZC) - 2022 - Only at Best Buy',
#  '(1650 Reviews)',
#  '$1399.99',
#  '$1,399.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'LG 55" 4K UHD HDR QNED webOS Smart TV (55QNED80UQA) - 2022 - Dark Titan Silver/Ashed Blue',
#  '(833 Reviews)',
#  '$899.99',
#  '$899.99',
#  'SAVE $200',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG 50" 4K UHD HDR LED webOS Smart TV (50UQ7590PUB) - 2022 - Dark Iron Grey',
#  '(30 Reviews)',
#  '$649.99',
#  '$649.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Amazon Fire TV 4-Series 50" 4K UHD HDR LED Smart TV (B08T6G1DCB) - 2021',
#  '(16 Reviews)',
#  '$499.99',
#  '$499.99',
#  'Available to ship',
#  'Available at nearby stores',
#  'TCL 5-Series 65" 4K UHD HDR QLED Smart Google TV (65S546-CA) - 2021',
#  '(223 Reviews)',
#  '$899.99',
#  '$899.99',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony W830K 32" 720p HD HDR LED Smart Google TV (KD32W830K) - 2022',
#  '(84 Reviews)',
#  '$399.99',
#  '$399.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 65" 4K UHD HDR LED Tizen Smart TV (UN65CU8000FXZC) - 2023',
#  '(153 Reviews)',
#  '$1099.99',
#  '$1,099.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Samsung 65" 4K UHD OLED Tizen Smart TV (QN65S95BAFXZC) - Open Box',
#  '(5 Reviews)',
#  '$2079.99',
#  '$2,079.99',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'LG G3 55" 4K UHD HDR OLED evo Gallery webOS Smart TV (OLED55G3PUA) - 2023 - Satin Silver',
#  '(56 Reviews)',
#  '$3099.99',
#  '$3,099.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG 42" 4K UHD HDR OLED webOS Evo ThinQ AI Smart TV (OLED42C3PUA) - 2023',
#  '(49 Reviews)',
#  '$1799.99',
#  '$1,799.99',
#  'SAVE $50',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony BRAVIA XR 77" 4K UHD HDR OLED Google TV Smart TV (XR77A80K) - 2022 - Titanium Black',
#  '(1134 Reviews)',
#  '$3999.99',
#  '$3,999.99',
#  'Plus $15.50 EHF',
#  'Sold out online',
#  'Sold out in nearby stores',
#  'Toshiba 75" 4K UHD HDR LED Smart TV (75C350KC) - Fire TV Edition - 2021 - Only at Best Buy',
#  '(4 Reviews)',
#  '$999.95',
#  '$999.95',
#  'SAVE $300',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 50" 4K UHD HDR LED Tizen Smart TV (UN50TU7000FXZC) - Titan Grey',
#  '(21276 Reviews)',
#  '$549.99',
#  '$549.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Available at nearby stores',
#  'Open Box - Samsung 55" 4K UHD HDR Mini-LED Tizen OS Smart TV (QN55QN90AAFXZC) - 2021 - Titan Black',
#  '(2 Reviews)',
#  '$1359.99',
#  '$1,359.99',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Samsung 98" 8K UHD HDR QLED Tizen Smart TV (QN98Q900RBFXZC)',
#  '(167 Reviews)',
#  '$99999.99',
#  '$99,999.99',
#  'Not sold online',
#  'Sold out in nearby stores',
#  'Samsung 75" 4K UHD HDR Neo QLED Tizen Smart TV (QN75QN88BAFXZC) - Titan Black',
#  '(6 Reviews)',
#  '$2599.99',
#  '$2,599.99',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'Sony BRAVIA XR A90K 42" 4K UHD HDR OLED Smart Google TV (XR42A90K) - 2022',
#  '(178 Reviews)',
#  '$1749.99',
#  '$1,749.99',
#  'Plus $12.20 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  'LG 70" 4K UHD HDR LED webOS Smart TV (70UQ7590PUB) - 2022 - Dark Iron Grey',
#  '(795 Reviews)',
#  '$1099.99',
#  '$1,099.99',
#  'SAVE $13',
#  'Plus $15.50 EHF',
#  'Available to ship',
#  'Sold out in nearby stores',
#  ...]

# %%
default = defaultdict(list)

# %%
for items in array:
    try:
        if 'Sponsored' in items.splitlines():
            default['description'].append(items.splitlines()[1])
            default['reviews'].append(items.splitlines()[2])
        else:
            default['description'].append(items.splitlines()[0])
            default['reviews'].append(items.splitlines()[1])

        if 'Top Deal' in items.splitlines() and 'Sponsored' in items.splitlines():
            default['Price'].append(items.splitlines()[4])
            default['Discount'].append(items.splitlines()[6])
        elif 'Top Deal' in items.splitlines() or 'Sponsored' in items.splitlines():
            default['Price'].append(items.splitlines()[3])
            default['Discount'].append(items.splitlines()[5])
        else:
            default['Price'].append(items.splitlines()[2])
            default['Discount'].append(items.splitlines()[4])
    except:
        print('No index')

# %%
df = pd.DataFrame.from_dict(default, orient='index')
df = df.transpose()

# %%
df.head()
# Out:
#                                          description         reviews    Price  \
# 0  LG 43" 4K UHD HDR LED webOS Smart TV (43UQ7590...  (1808 Reviews)  $449.99
#
#             Discount
# 0  Available to ship

# %%
len(df)
# Out:
# 1
